# %% [markdown]
# # 🛒 BasketAI — Market Basket Analysis System
# ### Apriori + FP-Growth + ECLAT | Recommendation Engine | Customer Segmentation
# ---
# **Run cells top to bottom. Every path is resolved automatically — no manual folder navigation needed.**

# %% [markdown]
# ## ⚙️ Cell 1 — Path Setup (run this FIRST)

# %%
import sys, os, warnings
warnings.filterwarnings('ignore')

def find_project_root():
    """Walk upward from cwd to find the folder containing app.py or ml_engine.py."""
    candidates = [os.getcwd()]
    for base in list(candidates):
        candidates += [os.path.join(base,'..'), os.path.join(base,'..','..') ]
    markers = ['app.py','ml_engine.py', os.path.join('backend','app.py')]
    for c in candidates:
        c = os.path.abspath(c)
        for m in markers:
            if os.path.exists(os.path.join(c,m)):
                return c
    return os.getcwd()

ROOT = find_project_root()

# Add every folder that could contain ml_engine.py
for p in [ROOT, os.path.join(ROOT,'backend'), os.path.join(ROOT,'..'), os.getcwd()]:
    p = os.path.abspath(p)
    if p not in sys.path:
        sys.path.insert(0, p)

# Resolve data directory
DATA_DIR = None
for dc in [os.path.join(ROOT,'data'), os.path.join(ROOT,'..','data'), os.path.join(os.getcwd(),'data')]:
    if os.path.isdir(os.path.abspath(dc)):
        DATA_DIR = os.path.abspath(dc)
        break
if DATA_DIR is None:
    DATA_DIR = os.path.join(ROOT,'data')
    os.makedirs(DATA_DIR, exist_ok=True)

DATASET = os.path.join(DATA_DIR, 'transactions.csv')

# Resolve app.py
APP_PY = next(
    (p for p in [os.path.join(ROOT,'app.py'), os.path.join(ROOT,'backend','app.py')] if os.path.exists(p)),
    os.path.join(ROOT,'app.py')
)

print(f'Project root : {ROOT}')
print(f'Data dir     : {DATA_DIR}')
print(f'Dataset      : {DATASET}  (exists={os.path.exists(DATASET)})')
print(f'app.py       : {APP_PY}   (exists={os.path.exists(APP_PY)})')
print('\n✅ Paths ready — run Cell 2')
# Out:
# Project root : C:\Users\kashi\OneDrive\Desktop\MARKET_BASKET_ANALYSIS
# Data dir     : C:\Users\kashi\OneDrive\Desktop\MARKET_BASKET_ANALYSIS\data
# Dataset      : C:\Users\kashi\OneDrive\Desktop\MARKET_BASKET_ANALYSIS\data\transactions.csv  (exists=True)
# app.py       : C:\Users\kashi\OneDrive\Desktop\MARKET_BASKET_ANALYSIS\app.py   (exists=True)
#
# ✅ Paths ready — run Cell 2

# %% [markdown]
# ## 📦 Cell 2 — Install Dependencies

# %%
import subprocess, importlib

PACKAGES = ['fastapi','uvicorn','python-multipart','pandas','numpy','scikit-learn','matplotlib']

def installed(pkg):
    try: importlib.import_module(pkg.split('[')[0].replace('-','_')); return True
    except ImportError: return False

missing = [p for p in PACKAGES if not installed(p)]
if missing:
    print(f'Installing: {missing} ...')
    subprocess.check_call([sys.executable,'-m','pip','install','--quiet']+missing)
print('✅ All packages ready')
# Out:
# Installing: ['scikit-learn'] ...
# ✅ All packages ready

# %% [markdown]
# ## 🔧 Cell 3 — Import ML Engine

# %%
import pandas as pd, numpy as np

try:
    from ml_engine import (
        load_transactions, run_full_analysis,
        Apriori, FPGrowth, ECLAT,
        RecommendationEngine, rank_rules,
        segment_customers, analyze_seasonality,
        build_product_graph, compare_models
    )
    print('✅ ml_engine imported')
except ModuleNotFoundError as e:
    print(f'❌ {e}')
    print('sys.path searched:')
    for p in sys.path: print(f'  {p}')
    raise
# Out:
# ✅ ml_engine imported

# %% [markdown]
# ## 📊 Cell 4 — Generate & Load Dataset

# %%
if not os.path.exists(DATASET):
    print('Generating sample data...')
    import random; from datetime import datetime, timedelta
    random.seed(42); np.random.seed(42)
    PRODS = {
        'Electronics':['Laptop','Mouse','Keyboard','Monitor','Webcam','Headphones','USB Hub','Laptop Stand','Charger','Speaker'],
        'Office':['Notebook','Pen Set','Desk Organizer','Stapler','Sticky Notes','File Folder','Whiteboard','Printer Paper','Scissors','Tape'],
        'Beverages':['Coffee','Green Tea','Protein Shake','Energy Drink','Water Bottle','Juice Pack','Herbal Tea','Cold Brew','Kombucha','Coconut Water'],
        'Snacks':['Granola Bar','Mixed Nuts','Dark Chocolate','Popcorn','Trail Mix','Rice Cakes','Protein Bar','Dried Fruit','Crackers','Yogurt'],
        'Health':['Vitamins','Omega-3','Protein Powder','Probiotics','Melatonin','Zinc','Vitamin D','Magnesium','Collagen','Turmeric'],
        'Fitness':['Resistance Band','Yoga Mat','Foam Roller','Jump Rope','Dumbbells','Water Bottle','Gym Gloves','Workout Towel','Ankle Weights','Balance Board'],
    }
    ASSOC = {'Laptop':['Mouse','Keyboard','Laptop Stand','USB Hub'],'Coffee':['Dark Chocolate','Granola Bar'],
             'Protein Shake':['Protein Bar','Resistance Band'],'Yoga Mat':['Foam Roller','Water Bottle'],
             'Vitamins':['Omega-3','Probiotics'],'Headphones':['Laptop','Speaker']}
    SEGS = {'tech_professional':{'cats':['Electronics','Office','Beverages'],'w':0.25},
            'health_enthusiast':{'cats':['Health','Fitness','Beverages','Snacks'],'w':0.30},
            'office_worker':{'cats':['Office','Beverages','Snacks'],'w':0.25},
            'student':{'cats':['Electronics','Office','Snacks','Beverages'],'w':0.20}}
    sn=list(SEGS.keys()); sw=[SEGS[s]['w'] for s in sn]
    start=datetime(2023,1,1); recs=[]
    for tid in range(1,2001):
        date=start+timedelta(days=random.randint(0,364))
        seg=random.choices(sn,weights=sw)[0]
        cid=f'CUST_{random.randint(1,500):04d}'
        basket=list(set([random.choice(PRODS[random.choice(SEGS[seg]['cats'])]) for _ in range(random.randint(2,8))]))
        for p in basket[:]:
            if p in ASSOC and random.random()<0.6: basket.append(random.choice(ASSOC[p]))
        for prod in set(basket):
            recs.append({'transaction_id':f'TXN_{tid:05d}','customer_id':cid,'product':prod,
                         'date':date.strftime('%Y-%m-%d'),'month':date.month,'day_of_week':date.strftime('%A'),
                         'customer_segment':seg,'quantity':random.randint(1,3),'price':round(random.uniform(5,200),2)})
    pd.DataFrame(recs).to_csv(DATASET,index=False)
    print(f'✅ Saved to {DATASET}')

df, basket_list, all_items = load_transactions(DATASET)
print(f'Transactions : {df["transaction_id"].nunique():,}')
print(f'Customers    : {df["customer_id"].nunique():,}')
print(f'Products     : {df["product"].nunique()}')
print(f'Date range   : {df["date"].min()} to {df["date"].max()}')
df.head(10)
# Out:
# Transactions : 2,000
# Customers    : 489
# Products     : 59
# Date range   : 2023-01-01 to 2023-12-31
#   transaction_id customer_id         product        date  month day_of_week  \
# 0      TXN_00001   CUST_0380         Speaker  2023-11-24     11      Friday
# 1      TXN_00001   CUST_0380           Mouse  2023-11-24     11      Friday
# 2      TXN_00001   CUST_0380        Kombucha  2023-11-24     11      Friday
# 3      TXN_00001   CUST_0380         Monitor  2023-11-24     11      Friday
# 4      TXN_00002   CUST_0215   Coconut Water  2023-11-29     11   Wednesday
# 5      TXN_00002   CUST_0215      Whiteboard  2023-11-29     11   Wednesday
# 6      TXN_00002   CUST_0215  Dark Chocolate  2023-11-29     11   Wednesday
# 7      TXN_00002   CUST_0215          Coffee  2023-11-29     11   Wednesday
# 8      TXN_00003   CUST_0275       Trail Mix  2023-01-23      1      Monday
# 9      TXN_00003   CUST_0275       Green Tea  2023-01-23      1      Monday
#
#     customer_segment  quantity   price
# 0  tech_professional         2   11.20
# 1  tech_professional         1   47.63
# 2  tech_professional         3  122.39
# 3  tech_professional         3   43.77
# 4      office_worker         1  191.66
# 5      office_worker         2   24.93
# 6      office_worker         2   23.86
# 7      office_worker         2  122.73
# 8      office_worker         3  125.61
# 9      office_worker         2  117.58

# %% [markdown]
# ## 🤖 Cell 5 — Algorithm Comparison

# %%
params = {'min_support':0.01,'min_confidence':0.20,'max_len':3}
print('Training Apriori, FP-Growth, ECLAT...')
comparison = compare_models(basket_list, params)
rows = [{'Algorithm':a,'Itemsets':d['n_frequent_itemsets'],'Rules':d['n_rules'],
         'Time(s)':d['training_time_sec'],'Avg Lift':d['avg_lift'],'Max Lift':d['max_lift']}
        for a,d in comparison.items()]
pd.DataFrame(rows).style.background_gradient(subset=['Rules','Avg Lift','Max Lift'], cmap='Blues')
# Out:
# Training Apriori, FP-Growth, ECLAT...
# <style type="text/css">
# #T_4a191_row0_col2, #T_4a191_row0_col4, #T_4a191_row0_col5 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4a191_row1_col2, #T_4a191_row1_col4, #T_4a191_row1_col5, #T_4a191_row2_col2, #T_4a191_row2_col4, #T_4a191_row2_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4a191">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a191_level0_col0" class="col_heading level0 col0" >Algorithm</th>
#       <th id="T_4a191_level0_col1" class="col_heading level0 col1" >Itemsets</th>
#       <th id="T_4a191_level0_col2" class="col_heading level0 col2" >Rules</th>
#       <th id="T_4a191_level0_col3" class="col_heading level0 col3" >Time(s)</th>
#       <th id="T_4a191_level0_col4" class="col_heading level0 col4" >Avg Lift</th>
#       <th id="T_4a191_level0_col5" class="col_heading level0 col5" >Max Lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a191_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a191_row0_col0" class="data row0 col0" >Apriori</td>
#       <td id="T_4a191_row0_col1" class="data row0 col1" >59</td>
#       <td id="T_4a191_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_4a191_row0_col3" class="data row0 col3" >0.602000</td>
#       <td id="T_4a191_row0_col4" class="data row0 col4" >0.000000</td>
#       <td id="T_4a191_row0_col5" class="data row0 col5" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4a191_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a191_row1_col0" class="data row1 col0" >FPGrowth</td>
#       <td id="T_4a191_row1_col1" class="data row1 col1" >502</td>
#       <td id="T_4a191_row1_col2" class="data row1 col2" >52</td>
#       <td id="T_4a191_row1_col3" class="data row1 col3" >0.851000</td>
#       <td id="T_4a191_row1_col4" class="data row1 col4" >2.662000</td>
#       <td id="T_4a191_row1_col5" class="data row1 col5" >5.714000</td>
#     </tr>
#     <tr>
#       <th id="T_4a191_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a191_row2_col0" class="data row2 col0" >ECLAT</td>
#       <td id="T_4a191_row2_col1" class="data row2 col1" >502</td>
#       <td id="T_4a191_row2_col2" class="data row2 col2" >52</td>
#       <td id="T_4a191_row2_col3" class="data row2 col3" >0.743000</td>
#       <td id="T_4a191_row2_col4" class="data row2 col4" >2.662000</td>
#       <td id="T_4a191_row2_col5" class="data row2 col5" >5.714000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🔗 Cell 6 — Top Association Rules

# %%
model = FPGrowth(**params)
model.fit(basket_list)
rules = rank_rules(model.rules)
print(f'Found {len(rules)} rules')
if rules:
    rdf = pd.DataFrame(rules)[['antecedents','consequents','support','confidence','lift','interestingness','algorithm']]
    rdf['antecedents'] = rdf['antecedents'].apply(lambda x:' + '.join(x))
    rdf['consequents'] = rdf['consequents'].apply(lambda x:' + '.join(x))
    display(rdf.head(15).style.background_gradient(subset=['lift','confidence','interestingness'], cmap='YlOrRd'))
# Out:
# Found 52 rules
# <style type="text/css">
# #T_fe266_row0_col3, #T_fe266_row0_col5, #T_fe266_row2_col4 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_fe266_row0_col4, #T_fe266_row4_col4 {
#   background-color: #fd9f44;
#   color: #000000;
# }
# #T_fe266_row1_col3 {
#   background-color: #d30f20;
#   color: #f1f1f1;
# }
# #T_fe266_row1_col4, #T_fe266_row11_col4 {
#   background-color: #fec45f;
#   color: #000000;
# }
# #T_fe266_row1_col5 {
#   background-color: #f23924;
#   color: #f1f1f1;
# }
# #T_fe266_row2_col3 {
#   background-color: #fee289;
#   color: #000000;
# }
# #T_fe266_row2_col5 {
#   background-color: #fd8439;
#   color: #f1f1f1;
# }
# #T_fe266_row3_col3 {
#   background-color: #feb54f;
#   color: #000000;
# }
# #T_fe266_row3_col4, #T_fe266_row5_col4 {
#   background-color: #f33b25;
#   color: #f1f1f1;
# }
# #T_fe266_row3_col5 {
#   background-color: #fd883b;
#   color: #f1f1f1;
# }
# #T_fe266_row4_col3 {
#   background-color: #ffefa5;
#   color: #000000;
# }
# #T_fe266_row4_col5 {
#   background-color: #feac49;
#   color: #000000;
# }
# #T_fe266_row5_col3 {
#   background-color: #ffec9d;
#   color: #000000;
# }
# #T_fe266_row5_col5 {
#   background-color: #feb651;
#   color: #000000;
# }
# #T_fe266_row6_col3 {
#   background-color: #fecf6b;
#   color: #000000;
# }
# #T_fe266_row6_col4 {
#   background-color: #f13624;
#   color: #f1f1f1;
# }
# #T_fe266_row6_col5 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_fe266_row7_col3 {
#   background-color: #fee187;
#   color: #000000;
# }
# #T_fe266_row7_col4, #T_fe266_row9_col4 {
#   background-color: #fc5f2f;
#   color: #f1f1f1;
# }
# #T_fe266_row7_col5 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_fe266_row8_col3 {
#   background-color: #d6111f;
#   color: #f1f1f1;
# }
# #T_fe266_row8_col4 {
#   background-color: #ffe998;
#   color: #000000;
# }
# #T_fe266_row8_col5 {
#   background-color: #fece6a;
#   color: #000000;
# }
# #T_fe266_row9_col3 {
#   background-color: #fff3af;
#   color: #000000;
# }
# #T_fe266_row9_col5 {
#   background-color: #fedf83;
#   color: #000000;
# }
# #T_fe266_row10_col3, #T_fe266_row14_col3 {
#   background-color: #fee38b;
#   color: #000000;
# }
# #T_fe266_row10_col4, #T_fe266_row12_col4 {
#   background-color: #fd9e43;
#   color: #000000;
# }
# #T_fe266_row10_col5 {
#   background-color: #ffe58f;
#   color: #000000;
# }
# #T_fe266_row11_col3, #T_fe266_row13_col4, #T_fe266_row14_col4, #T_fe266_row14_col5 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_fe266_row11_col5 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_fe266_row12_col3 {
#   background-color: #fff8ba;
#   color: #000000;
# }
# #T_fe266_row12_col5 {
#   background-color: #fff2ac;
#   color: #000000;
# }
# #T_fe266_row13_col3 {
#   background-color: #fee084;
#   color: #000000;
# }
# #T_fe266_row13_col5 {
#   background-color: #fffdc8;
#   color: #000000;
# }
# </style>
# <table id="T_fe266">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe266_level0_col0" class="col_heading level0 col0" >antecedents</th>
#       <th id="T_fe266_level0_col1" class="col_heading level0 col1" >consequents</th>
#       <th id="T_fe266_level0_col2" class="col_heading level0 col2" >support</th>
#       <th id="T_fe266_level0_col3" class="col_heading level0 col3" >confidence</th>
#       <th id="T_fe266_level0_col4" class="col_heading level0 col4" >lift</th>
#       <th id="T_fe266_level0_col5" class="col_heading level0 col5" >interestingness</th>
#       <th id="T_fe266_level0_col6" class="col_heading level0 col6" >algorithm</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe266_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fe266_row0_col0" class="data row0 col0" >Gym Gloves</td>
#       <td id="T_fe266_row0_col1" class="data row0 col1" >Protein Shake</td>
#       <td id="T_fe266_row0_col2" class="data row0 col2" >0.037500</td>
#       <td id="T_fe266_row0_col3" class="data row0 col3" >0.535700</td>
#       <td id="T_fe266_row0_col4" class="data row0 col4" >3.733200</td>
#       <td id="T_fe266_row0_col5" class="data row0 col5" >0.411400</td>
#       <td id="T_fe266_row0_col6" class="data row0 col6" >FP-Growth</td>
#     </tr>
#     <tr>
#       <th id="T_fe266_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fe266_row1_col0" class="data row1 col0" >Resistance Band</td>
#       <td id="T_fe266_row1_col1" class="data row1 col1" >Protein Shake</td>
#       <td id="T_fe266_row1_col2" class="data row1 col2" >0.032500</td>
#       <td id="T_fe266_row1_col3" class="data row1 col3" >0.474500</td>
#       <td id="T_fe266_row1_col4" class="data row1 col4" >3.306300</td>
#       <td id="T_fe266_row1_col5" class="data row1 col5" >0.360400</td>
#       <td id="T_fe266_row1_col6" class="data row1 col6" >FP-Growth</td>
#     </tr>
#     <tr>
#       <th id="T_fe266_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fe266_row2_col0" class="data row2 col0" >Yoga Mat</td>
#       <td id="T_fe266_row2_col1" class="data row2 col1" >Foam Roller</td>
#       <td id="T_fe266_row2_col2" class="data row2 col2" >0.010000</td>
#       <td id="T_fe266_row2_col3" class="data row2 col3" >0.285700</td>
#       <td id="T_fe266_row2_col4" class="data row2 col4" >5.714300</td>
#       <td id="T_fe266_row2_col5" class="data row2 col5" >0.336400</td>
#       <td id="T_fe266_row2_col6" class="data row2 col6" >FP-Growth</td>
#     </tr>
#     <tr>
#       <th id="T_fe266_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fe266_row3_col0" class="data row3 col0" >Headphones</td>
#       <td id="T_fe266_row3_col1" class="data row3 col1" >USB Hub</td>
#       <td id="T_fe266_row3_col2" class="data row3 col2" >0.020000</td>
#       <td id="T_fe266_row3_col3" class="data row3 col3" >0.339000</td>
#       <td id="T_fe266_row3_col4" class="data row3 col4" >4.550100</td>
#       <td id="T_fe266_row3_col5" class="data row3 col5" >0.335200</td>
#       <td id="T_fe266_row3_col6" class="data row3 col6" >FP-Growth</td>
#     </tr>
#     <tr>
#       <th id="T_fe266_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fe266_row4_col0" class="data row4 col0" >Protein Shake</td>
#       <td id="T_fe266_row4_col1" class="data row4 col1" >Gym Gloves</td>
#       <td id="T_fe266_row4_col2" class="data row4 col2" >0.037500</td>
#       <td id="T_fe266_row4_col3" class="data row4 col3" >0.261300</td>
#       <td id="T_fe266_row4_col4" class="data row4 col4" >3.733200</td>
#       <td id="T_fe266_row4_col5" class="data row4 col5" >0.317400</td>
#       <td id="T_fe266_row4_col6" class="data row4 col6" >FP-Growth</td>
#     </tr>
#     <tr>
#       <th id="T_fe266_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fe266_row5_col0" class="data row5 col0" >USB Hub</td>
#       <td id="T_fe266_row5_col1" class="data row5 col1" >Headphones</td>
#       <td id="T_fe266_row5_col2" class="data row5 col2" >0.020000</td>
#       <td id="T_fe266_row5_col3" class="data row5 col3" >0.268500</td>
#       <td id="T_fe266_row5_col4" class="data row5 col4" >4.550100</td>
#       <td id="T_fe266_row5_col5" class="data row5 col5" >0.311700</td>
#       <td id="T_fe266_row5_col6" class="data row5 col6" >FP-Growth</td>
#     </tr>
#     <tr>
#       <th id="T_fe266_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fe266_row6_col0" class="data row6 col0" >Yoga Mat</td>
#       <td id="T_fe266_row6_col1" class="data row6 col1" >Resistance Band</td>
#       <td id="T_fe266_row6_col2" class="data row6 col2" >0.011000</td>
#       <td id="T_fe266_row6_col3" class="data row6 col3" >0.314300</td>
#       <td id="T_fe266_row6_col4" class="data row6 col4" >4.588100</td>
#       <td id="T_fe266_row6_col5" class="data row6 col5" >0.307500</td>
#       <td id="T_fe266_row6_col6" class="data row6 col6" >FP-Growth</td>
#     </tr>
#     <tr>
#       <th id="T_fe266_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fe266_row7_col0" class="data row7 col0" >Headphones</td>
#       <td id="T_fe266_row7_col1" class="data row7 col1" >Speaker</td>
#       <td id="T_fe266_row7_col2" class="data row7 col2" >0.017000</td>
#       <td id="T_fe266_row7_col3" class="data row7 col3" >0.288100</td>
#       <td id="T_fe266_row7_col4" class="data row7 col4" >4.268700</td>
#       <td id="T_fe266_row7_col

# %% [markdown]
# ## 🔮 Cell 7 — Recommendation Engine

# %%
rec_engine = RecommendationEngine()
rec_engine.fit(rules)
for cart in [['Laptop','Mouse'],['Yoga Mat','Water Bottle'],['Coffee','Notebook']]:
    r = rec_engine.recommend(cart, n=3)
    print(f'\n🛒 Cart: {cart}')
    for u in r['upsell']:   print(f'  ⬆️  {u["product"]} (lift={u["lift"]:.2f}) — {u["explanation"]}')
    for c in r['cross_sell']: print(f'  ↔️  {c["product"]} (lift={c["lift"]:.2f})')
    if not r['upsell'] and not r['cross_sell']: print('  ℹ️  No strong associations')
# Out:
# 🛒 Cart: ['Laptop', 'Mouse']
#   ⬆️  Keyboard (lift=3.74) — Customers who buy Laptop very strongly tend to also purchase Keyboard (28% of the time, 3.7x more likely).
#   ⬆️  USB Hub (lift=3.30) — Customers who buy Laptop very strongly tend to also purchase USB Hub (24% of the time, 3.3x more likely).
#   ⬆️  Headphones (lift=3.65) — Customers who buy Laptop very strongly tend to also purchase Headphones (21% of the time, 3.7x more likely).
#
# 🛒 Cart: ['Yoga Mat', 'Water Bottle']
#   ⬆️  Foam Roller (lift=5.71) — Customers who buy Yoga Mat very strongly tend to also purchase Foam Roller (28% of the time, 5.7x more likely).
#   ⬆️  Resistance Band (lift=4.59) — Customers who buy Yoga Mat very strongly tend to also purchase Resistance Band (31% of the time, 4.6x more likely).
#
# 🛒 Cart: ['Coffee', 'Notebook']
#   ⬆️  Granola Bar (lift=2.18) — Customers who buy Coffee strongly tend to also purchase Granola Bar (29% of the time, 2.2x more likely).
#   ⬆️  Dark Chocolate (lift=2.07) — Customers who buy Coffee strongly tend to also purchase Dark Chocolate (26% of the time, 2.1x more likely).

# %% [markdown]
# ## 👥 Cell 8 — Customer Segmentation

# %%
customer_segs = segment_customers(df)
print(customer_segs['segment'].value_counts())
customer_segs.groupby('segment')[['total_spend','n_transactions','n_unique_products']].mean().round(2)
# Out:
# segment
# Premium Customers    192
# Occasional Buyers    117
# Frequent Buyers      113
# Budget Shoppers       67
# Name: count, dtype: int64
#                    total_spend  n_transactions  n_unique_products
# segment
# Budget Shoppers         817.48            2.13               8.87
# Frequent Buyers        1178.91            2.19               9.36
# Occasional Buyers      3602.16            6.80              25.91
# Premium Customers      2025.52            4.23              17.50

# %% [markdown]
# ## 📅 Cell 9 — Seasonality Analysis

# %%
season = analyze_seasonality(df)
tdf    = pd.DataFrame(season['trend_data'])
top3   = season['top_products'][:3]
tdf[['month']+top3].style.background_gradient(subset=top3, cmap='Blues')
# Out:
# <style type="text/css">
# #T_9cd2f_row0_col1 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_9cd2f_row0_col2, #T_9cd2f_row3_col3, #T_9cd2f_row5_col1, #T_9cd2f_row6_col1, #T_9cd2f_row6_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9cd2f_row0_col3 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_9cd2f_row1_col1, #T_9cd2f_row9_col1 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_9cd2f_row1_col2, #T_9cd2f_row3_col2 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_9cd2f_row1_col3 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_9cd2f_row2_col1, #T_9cd2f_row7_col1 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_9cd2f_row2_col2, #T_9cd2f_row8_col2 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_9cd2f_row2_col3, #T_9cd2f_row10_col3 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_9cd2f_row3_col1, #T_9cd2f_row7_col3, #T_9cd2f_row10_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9cd2f_row4_col1 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_9cd2f_row4_col2, #T_9cd2f_row7_col2 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_9cd2f_row4_col3 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_9cd2f_row5_col2, #T_9cd2f_row9_col2 {
#   background-color: #1764ab;
#   color: #f1f1f1;
# }
# #T_9cd2f_row5_col3, #T_9cd2f_row9_col3 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_9cd2f_row6_col3, #T_9cd2f_row11_col3 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_9cd2f_row8_col1 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_9cd2f_row8_col3 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_9cd2f_row10_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_9cd2f_row11_col1 {
#   background-color: #08509b;
#   color: #f1f1f1;
# }
# #T_9cd2f_row11_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# </style>
# <table id="T_9cd2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cd2f_level0_col0" class="col_heading level0 col0" >month</th>
#       <th id="T_9cd2f_level0_col1" class="col_heading level0 col1" >Water Bottle</th>
#       <th id="T_9cd2f_level0_col2" class="col_heading level0 col2" >Herbal Tea</th>
#       <th id="T_9cd2f_level0_col3" class="col_heading level0 col3" >Protein Shake</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cd2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9cd2f_row0_col0" class="data row0 col0" >Jan</td>
#       <td id="T_9cd2f_row0_col1" class="data row0 col1" >26</td>
#       <td id="T_9cd2f_row0_col2" class="data row0 col2" >32</td>
#       <td id="T_9cd2f_row0_col3" class="data row0 col3" >26</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9cd2f_row1_col0" class="data row1 col0" >Feb</td>
#       <td id="T_9cd2f_row1_col1" class="data row1 col1" >31</td>
#       <td id="T_9cd2f_row1_col2" class="data row1 col2" >20</td>
#       <td id="T_9cd2f_row1_col3" class="data row1 col3" >20</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9cd2f_row2_col0" class="data row2 col0" >Mar</td>
#       <td id="T_9cd2f_row2_col1" class="data row2 col1" >27</td>
#       <td id="T_9cd2f_row2_col2" class="data row2 col2" >25</td>
#       <td id="T_9cd2f_row2_col3" class="data row2 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9cd2f_row3_col0" class="data row3 col0" >Apr</td>
#       <td id="T_9cd2f_row3_col1" class="data row3 col1" >20</td>
#       <td id="T_9cd2f_row3_col2" class="data row3 col2" >20</td>
#       <td id="T_9cd2f_row3_col3" class="data row3 col3" >31</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9cd2f_row4_col0" class="data row4 col0" >May</td>
#       <td id="T_9cd2f_row4_col1" class="data row4 col1" >25</td>
#       <td id="T_9cd2f_row4_col2" class="data row4 col2" >22</td>
#       <td id="T_9cd2f_row4_col3" class="data row4 col3" >18</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9cd2f_row5_col0" class="data row5 col0" >Jun</td>
#       <td id="T_9cd2f_row5_col1" class="data row5 col1" >36</td>
#       <td id="T_9cd2f_row5_col2" class="data row5 col2" >29</td>
#       <td id="T_9cd2f_row5_col3" class="data row5 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9cd2f_row6_col0" class="data row6 col0" >Jul</td>
#       <td id="T_9cd2f_row6_col1" class="data row6 col1" >36</td>
#       <td id="T_9cd2f_row6_col2" class="data row6 col2" >32</td>
#       <td id="T_9cd2f_row6_col3" class="data row6 col3" >23</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9cd2f_row7_col0" class="data row7 col0" >Aug</td>
#       <td id="T_9cd2f_row7_col1" class="data row7 col1" >27</td>
#       <td id="T_9cd2f_row7_col2" class="data row7 col2" >22</td>
#       <td id="T_9cd2f_row7_col3" class="data row7 col3" >14</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9cd2f_row8_col0" class="data row8 col0" >Sep</td>
#       <td id="T_9cd2f_row8_col1" class="data row8 col1" >23</td>
#       <td id="T_9cd2f_row8_col2" class="data row8 col2" >25</td>
#       <td id="T_9cd2f_row8_col3" class="data row8 col3" >22</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9cd2f_row9_col0" class="data row9 col0" >Oct</td>
#       <td id="T_9cd2f_row9_col1" class="data row9 col1" >31</td>
#       <td id="T_9cd2f_row9_col2" class="data row9 col2" >29</td>
#       <td id="T_9cd2f_row9_col3" class="data row9 col3" >30</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9cd2f_row10_col0" class="data row10 col0" >Nov</td>
#       <td id="T_9cd2f_row10_col1" class="data row10 col1" >32</td>
#       <td id="T_9cd2f_row10_col2" class="data row10 col2" >17</td>
#       <td id="T_9cd2f_row10_col3" class="data row10 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_9cd2f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9cd2f_row11_col0" class="data row11 col0" >Dec</td>
#       <td id="T_9cd2f_row11_col1" class="data row11 col1" >34</td>
#       <td id="T_9cd2f_row11_col2" class="data row11 col2" >24</td>
#       <td id="T_9cd2f_row11_col3" class="data row11 col3" >23</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 📊 Cell 10 — Matplotlib Dashboard

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')
fig, axes = plt.subplots(2,2,figsize=(14,10))
fig.patch.set_facecolor('#050810')
clrs = ['#3b82f6','#06b6d4','#8b5cf6','#f59e0b','#10b981']

ax=axes[0,0]; ax.set_facecolor('#0c1120')
algos=[a for a in comparison]; nr=[comparison[a]['n_rules'] for a in algos]
bars=ax.bar(algos,nr,color=clrs[:3],edgecolor='none',alpha=0.85)
ax.set_title('Rules per Algorithm',color='#e2e8f0',pad=10)
ax.tick_params(colors='#64748b')
for s in ['top','right','left']: ax.spines[s].set_visible(False)
ax.spines['bottom'].set_color('#1e293b')
for b,v in zip(bars,nr): ax.text(b.get_x()+b.get_width()/2,v+.05,str(v),ha='center',color='#e2e8f0')

ax=axes[0,1]; ax.set_facecolor('#0c1120')
lifts=[r['lift'] for r in rules]
if lifts:
    ax.hist(lifts,bins=max(5,len(lifts)//2),color='#3b82f6',alpha=0.85,edgecolor='#0c1120')
    ax.axvline(np.mean(lifts),color='#06b6d4',linestyle='--',label=f'Mean {np.mean(lifts):.2f}')
    ax.legend(labelcolor='#e2e8f0',framealpha=0)
ax.set_title('Lift Distribution',color='#e2e8f0',pad=10); ax.tick_params(colors='#64748b')
for s in ['top','right']: ax.spines[s].set_visible(False)
for s in ['bottom','left']: ax.spines[s].set_color('#1e293b')

ax=axes[1,0]; ax.set_facecolor('#0c1120')
tp=df['product'].value_counts().head(10)
ax.barh(tp.index[::-1],tp.values[::-1],color=[clrs[i%len(clrs)] for i in range(10)],alpha=0.85)
ax.set_title('Top 10 Products',color='#e2e8f0',pad=10); ax.tick_params(colors='#64748b')
for s in ['top','right']: ax.spines[s].set_visible(False)
for s in ['bottom','left']: ax.spines[s].set_color('#1e293b')

ax=axes[1,1]; ax.set_facecolor('#0c1120')
sc=customer_segs['segment'].value_counts()
wedges,texts,autos=ax.pie(sc.values,labels=sc.index,autopct='%1.1f%%',
    colors=['#3b82f6','#06b6d4','#8b5cf6','#f59e0b'],
    textprops={'color':'#e2e8f0','fontsize':9},wedgeprops={'edgecolor':'#050810','linewidth':2})
for a in autos: a.set_color('#e2e8f0')
ax.set_title('Customer Segments',color='#e2e8f0',pad=10)

plt.suptitle('BasketAI Dashboard',color='#e2e8f0',fontsize=15,fontweight='bold',y=1.01)
plt.tight_layout()
save_path=os.path.join(ROOT,'analysis_dashboard.png')
plt.savefig(save_path,dpi=150,bbox_inches='tight',facecolor='#050810')
plt.show()
print(f'Chart saved → {save_path}')
# Out:
# Chart saved → C:\Users\kashi\OneDrive\Desktop\MARKET_BASKET_ANALYSIS\analysis_dashboard.png

# %% [markdown]
# ## 🚀 Cell 11 — Start FastAPI Backend Server

# %%
import subprocess, threading, time, urllib.request

def server_up():
    try: urllib.request.urlopen('http://localhost:8000/',timeout=2); return True
    except: return False

if server_up():
    print('✅ Server already running on http://localhost:8000')
elif not os.path.exists(APP_PY):
    print(f'❌ app.py not found at: {APP_PY}')
else:
    app_dir = os.path.dirname(os.path.abspath(APP_PY))
    print(f'Starting server from: {app_dir}')

    # On Windows use CREATE_NO_WINDOW so no extra console pops up
    kwargs = {}
    if os.name == 'nt':
        kwargs['creationflags'] = subprocess.CREATE_NO_WINDOW

    proc = subprocess.Popen(
        [sys.executable, '-m', 'uvicorn', 'app:app',
         '--host', '0.0.0.0', '--port', '8000'],
        cwd=app_dir,          # ← KEY FIX: run from the folder that contains app.py
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        **kwargs
    )

    print('Waiting for server', end='')
    for _ in range(25):
        time.sleep(1); print('.', end='', flush=True)
        if server_up(): break
    print()

    if server_up():
        print('\n✅ Server running!')
    else:
        try:
            out, _ = proc.communicate(timeout=2)
            print('\nServer output:\n', out.decode()[:1500])
        except subprocess.TimeoutExpired:
            print('\n⚠️  Still starting — wait a few seconds then run Cell 12')

print('\n📖 API docs: http://localhost:8000/docs')
# Out:
# ✅ Server already running on http://localhost:8000
#
# 📖 API docs: http://localhost:8000/docs

# %% [markdown]
# ## 🎨 Cell 12 — Verify API & Open Frontend

# %%
import json, urllib.request
from IPython.display import HTML, display

def api_get(path):
    try:
        r=urllib.request.urlopen(f'http://localhost:8000{path}',timeout=5)
        return json.loads(r.read())
    except Exception as e: return {'error':str(e)}

def api_post(path,data):
    try:
        payload=json.dumps(data).encode()
        req=urllib.request.Request(f'http://localhost:8000{path}',data=payload,
                                   headers={'Content-Type':'application/json'},method='POST')
        return json.loads(urllib.request.urlopen(req,timeout=10).read())
    except Exception as e: return {'error':str(e)}

status  = api_get('/api/status')
recs    = api_post('/api/recommend',{'cart':['Laptop','Mouse'],'n_recommendations':3})

print(f'Server alive  : {"✅" if "error" not in status else "❌ "+status.get("error","")}')
print(f'Model ready   : {"✅" if status.get("training_status")=="ready" else "⚠️  wait 10s and rerun"}')
if 'error' not in recs:
    print(f'\nUpsell  : {[r["product"] for r in recs.get("upsell",[])[:3]]}')
    print(f'CrossSell: {[r["product"] for r in recs.get("cross_sell",[])[:3]]}')

# Locate frontend
FRONTEND = next(
    (os.path.abspath(p) for p in [
        os.path.join(ROOT,'frontend','index.html'),
        os.path.join(ROOT,'..','frontend','index.html'),
        os.path.join(os.getcwd(),'frontend','index.html')
    ] if os.path.exists(p)),
    'frontend/index.html (not found)'
)

display(HTML(f"""
<div style="margin-top:20px;background:linear-gradient(135deg,#0c1120,#111827);
  border:1px solid rgba(59,130,246,0.35);border-radius:16px;padding:24px;
  font-family:sans-serif;color:#e2e8f0;max-width:640px;">
  <h2 style="margin:0 0 12px;background:linear-gradient(135deg,#3b82f6,#06b6d4);
    -webkit-background-clip:text;-webkit-text-fill-color:transparent;">◈ BasketAI Ready</h2>
  <div style="display:flex;flex-direction:column;gap:10px;">
    <a href='http://localhost:8000/docs' target='_blank'
       style='background:rgba(59,130,246,0.18);border:1px solid rgba(59,130,246,0.4);
       border-radius:10px;padding:12px 18px;color:#60a5fa;text-decoration:none;font-weight:600;'>
       🔌 API Docs → http://localhost:8000/docs</a>
    <div style='background:rgba(16,185,129,0.1);border:1px solid rgba(16,185,129,0.35);
      border-radius:10px;padding:12px 18px;color:#34d399;font-weight:600;'>
      🎨 Open in browser:<br/>
      <code style='font-size:0.82rem;background:rgba(0,0,0,0.3);padding:2px 6px;border-radius:4px;'>{FRONTEND}</code>
    </div>
    <div style='background:rgba(139,92,246,0.1);border:1px solid rgba(139,92,246,0.3);
      border-radius:10px;padding:10px 18px;color:#a78bfa;font-size:0.85rem;'>
      💡 In JupyterLab right-click <b>frontend/index.html</b> → Open With → HTML Viewer
    </div>
  </div>
</div>
"""))
# Out:
# Server alive  : ✅
# Model ready   : ✅
#
# Upsell  : ['Keyboard', 'USB Hub', 'Headphones']
# CrossSell: []
# <div style="margin-top:20px;background:linear-gradient(135deg,#0c1120,#111827);
#   border:1px solid rgba(59,130,246,0.35);border-radius:16px;padding:24px;
#   font-family:sans-serif;color:#e2e8f0;max-width:640px;">
#   <h2 style="margin:0 0 12px;background:linear-gradient(135deg,#3b82f6,#06b6d4);
#     -webkit-background-clip:text;-webkit-text-fill-color:transparent;">◈ BasketAI Ready</h2>
#   <div style="display:flex;flex-direction:column;gap:10px;">
#     <a href='http://localhost:8000/docs' target='_blank'
#        style='background:rgba(59,130,246,0.18);border:1px solid rgba(59,130,246,0.4);
#        border-radius:10px;padding:12px 18px;color:#60a5fa;text-decoration:none;font-weight:600;'>
#        🔌 API Docs → http://localhost:8000/docs</a>
#     <div style='background:rgba(16,185,129,0.1);border:1px solid rgba(16,185,129,0.35);
#       border-radius:10px;padding:12px 18px;color:#34d399;font-weight:600;'>
#       🎨 Open in browser:<br/>
#       <code style='font-size:0.82rem;background:rgba(0,0,0,0.3);padding:2px 6px;border-radius:4px;'>frontend/index.html (not found)</code>
#     </div>
#     <div style='background:rgba(139,92,246,0.1);border:1px solid rgba(139,92,246,0.3);
#       border-radius:10px;padding:10px 18px;color:#a78bfa;font-size:0.85rem;'>
#       💡 In JupyterLab right-click <b>frontend/index.html</b> → Open With → HTML Viewer
#     </div>
#   </div>
# </div>
